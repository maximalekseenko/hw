# %%
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt

G = nx.gnp_random_graph(10, 0.5)


plt.figure(figsize =(7, 10))
plt.subplot(211)
nx.draw_networkx(G)
plt.show()

nx.shortest_path(G, source=0, target=9, method='dijkstra')
# Out:
# [0, 5, 9]
